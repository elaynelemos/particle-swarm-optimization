# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  
import numpy as np
import random

# %% [markdown]
# ### Superfície alvo:

# %%
def math_function(x, y):
    return -np.sin(5 * (x**2/121*np.pi + y**2/121*np.pi))

# %%
def plot_function():
    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(111, projection='3d')
    x = y = np.arange(-3, 3, 0.025)
    X, Y = np.meshgrid(x, y)
    zs = np.array(math_function(np.ravel(X), np.ravel(Y)))
    Z = zs.reshape(X.shape)
    
    ax.plot_surface(X, Y, Z, cmap='jet')
    x_max = y_max = z_max = -float('inf')
    for v1 in x:
        for v2 in y:
            z = math_function(v1, v2)
            if z > z_max:
                x_max = v1
                y_max = v2
                z_max = z 
    ax.scatter3D(x_max, y_max, z_max, s=500, color='g')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('f(x, y)')
    ax.set_title('Sin function')
    
    print(f'Max point: f({x_max}, {y_max}) = {z_max}')

    plt.show()

# %%
plot_function()
# Out:
# Max point: f(-1.0658141036401503e-14, -1.0658141036401503e-14) = -2.949357569708261e-29

# %% [markdown]
# ### Particle Swarm Optimization:

# %%
from particle_swarm_optimization.particle_swarm_optimization import swarm_main

# %%
swarm_main()
# Out:
# I am at [-0.43607028 -1.86109925] my pbest is [-0.43607028 -1.86109925]
# I am at [1.61335075 2.42385842] my pbest is [1.61335075 2.42385842]
# I am at [1.21268235 2.50272877] my pbest is [1.21268235 2.50272877]
# I am at [ 2.38379468 -2.29088433] my pbest is [ 2.38379468 -2.29088433]
# I am at [ 0.18235334 -1.38675527] my pbest is [ 0.18235334 -1.38675527]
# I am at [-1.96466692  2.96229441] my pbest is [-1.96466692  2.96229441]
# I am at [-1.09604668 -1.05875176] my pbest is [-1.09604668 -1.05875176]
# I am at [ 1.68386786 -0.98932241] my pbest is [ 1.68386786 -0.98932241]
# I am at [2.27333543 0.84938464] my pbest is [2.27333543 0.84938464]
# I am at [ 2.77207156 -1.11314629] my pbest is [ 2.77207156 -1.11314629]
# I am at [-1.01625992  1.72450168] my pbest is [-1.01625992  1.72450168]
# I am at [ 1.28281352 -1.50381904] my pbest is [ 1.28281352 -1.50381904]
# I am at [ 0.51210839 -0.57646679] my pbest is [ 0.51210839 -0.57646679]
# ...
