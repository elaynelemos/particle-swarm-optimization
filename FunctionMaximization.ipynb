# %% [markdown]
# ## Superfície alvo:

# %% [markdown]
# #### Função matemática
# $f(x, y) = 5 - 2 \times \sin(3 \times (\frac{(\frac{x}{4})^2}\pi + \frac{(\frac{y}{5})^2}\pi)$
#
# #### Plotando a função escolhida

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  
import numpy as np
import random

# %%
def math_function(x, y):
    return 5 - 2*np.sin(3 * ((x/4)**2/np.pi + (y/5)**2/np.pi))

# %%
def plot_max_point(x: list, y: list, plotable):
    x_max = y_max = z_max = -float('inf')
    for (v1, v2) in [(a,b) for a in x for b in y]:
        z = math_function(v1, v2)
        if z > z_max:
            x_max = v1
            y_max = v2
            z_max = z

    plotable.scatter3D(x_max, y_max, z_max, s=500, color='g')
    print(f'Max point: f({x_max}, {y_max}) = {z_max}')

# %%
def plot_function():
    x = y = np.arange(-5, 5, 0.025)
    X, Y = np.meshgrid(x, y)
    zs = np.array(math_function(np.ravel(X), np.ravel(Y)))
    Z = zs.reshape(X.shape)

    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(111, projection='3d')
    ax.plot_surface(X, Y, Z, cmap='jet')

    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('f(x, y)')
    ax.set_title('Sin function')

    plot_max_point(x, y, ax)
    plt.show()

# %%
plot_function()
# Out:
# Max point: f(7.105427357601002e-14, 7.105427357601002e-14) = 5.0

# %% [markdown]
# ### Particle Swarm Optimization:

# %%
from particle_swarm_optimization.particle_swarm_optimization import optimize

# %%
# optimize(target: float, target_error: float, iterations: int, swarm_size: int)
optimize(5.0, 1e-8, 50, 30)
# Out:
# This particle position: [-1.74894519  4.86327399]
# This particle position: [-3.28562853 -4.76714064]
# This particle position: [ 2.45833345 -4.42434352]
# This particle position: [ 3.62904267 -4.16247825]
# This particle position: [-4.62979492 -1.6779599 ]
# This particle position: [-1.81065269  4.937256  ]
# This particle position: [ 1.11320469 -2.4303319 ]
# This particle position: [0.28136379 2.99209586]
# This particle position: [0.59883689 2.88655988]
# This particle position: [ 1.79514589 -2.44206802]
# This particle position: [2.67195844 2.87390057]
# This particle position: [-3.79091723 -3.26451168]
# This particle position: [1.72237052 4.45091657]
# This particle position: [4.86704129 1.57483388]
# This particle position: [-0.51235943 -4.98423773]
# This particle position: [2.78539588 3.51296048]
# This particle position: [3.62898773 0.0710348 ]
# This particle position: [3.98007471 0.89949848]
# This particle position: [-2.0550074   4.44047145]
# ...
